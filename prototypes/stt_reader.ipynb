# %%
from RealtimeSTT import AudioToTextRecorder
recorder = AudioToTextRecorder(spinner=False, gpu_device_index=0, enable_realtime_transcription=True, realtime_processing_pause=0.1, on_realtime_transcription_stabilized=(lambda x: print(x)))

# %%
# def process_text(text):
    # print(text)

if __name__ == '__main__':
    print("Wait until it says 'speak now'")

    while True:
        recorder.text()
